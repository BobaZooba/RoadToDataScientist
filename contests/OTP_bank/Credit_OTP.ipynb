# %%
# Импортируем необходимые библиотеки
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import display
plt.rc('font', family='Verdana')

# %%
# Увеличиваем количество отображаемых столбцов датафрейма
pd.set_option('display.max_columns', 60)

# Считываем данные
data = pd.read_csv("Credit_OTP.csv", encoding='cp1251', sep = ';')
data.head()
# Out:
#    AGREEMENT_RK  TARGET  AGE  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  GENDER  \
# 0      59910150       0   49                  1                  0       1
# 1      59910230       0   32                  1                  0       1
# 2      59910525       0   52                  1                  0       1
# 3      59910803       0   39                  1                  0       1
# 4      59911781       0   30                  1                  0       0
#
#    CHILD_TOTAL  DEPENDANTS            EDUCATION  MARITAL_STATUS  \
# 0            2           1  Среднее специальное  Состою в браке
# 1            3           3              Среднее  Состою в браке
# 2            4           0     Неполное среднее  Состою в браке
# 3            1           1               Высшее  Состою в браке
# 4            0           0              Среднее  Состою в браке
#
#                 GEN_INDUSTRY                    GEN_TITLE  \
# 0                   Торговля                      Рабочий
# ...

# %%
data.describe()
# Out:
#        AGREEMENT_RK        TARGET           AGE  SOCSTATUS_WORK_FL  \
# count  1.522300e+04  15223.000000  15223.000000       15223.000000
# mean   6.540183e+07      0.119030     40.406096           0.909610
# std    4.568181e+06      0.323835     11.601068           0.286748
# min    5.991015e+07      0.000000     21.000000           0.000000
# 25%    6.192092e+07      0.000000     30.000000           1.000000
# 50%    6.437100e+07      0.000000     39.000000           1.000000
# 75%    6.708802e+07      0.000000     50.000000           1.000000
# max    7.529224e+07      1.000000     67.000000           1.000000
#
#        SOCSTATUS_PENS_FL        GENDER   CHILD_TOTAL    DEPENDANTS  \
# count       15223.000000  15223.000000  15223.000000  15223.000000
# mean            0.134468      0.654536      1.099389      0.645208
# std             0.341165      0.475535      0.995411      0.812252
# min             0.000000      0.000000      0.000000      0.000000
# ...

# %%
data.isnull().describe()
# Out:
#        AGREEMENT_RK TARGET    AGE SOCSTATUS_WORK_FL SOCSTATUS_PENS_FL GENDER  \
# count         15223  15223  15223             15223             15223  15223
# unique            1      1      1                 1                 1      1
# top           False  False  False             False             False  False
# freq          15223  15223  15223             15223             15223  15223
#
#        CHILD_TOTAL DEPENDANTS EDUCATION MARITAL_STATUS GEN_INDUSTRY GEN_TITLE  \
# count        15223      15223     15223          15223        15223     15223
# unique           1          1         1              1            2         2
# top          False      False     False          False        False     False
# freq         15223      15223     15223          15223        13856     13856
#
#        ORG_TP_STATE ORG_TP_FCAPITAL JOB_DIR FAMILY_INCOME PERSONAL_INCOME  \
# count         15223           15223   15223         15223           15223
# ...

# %%
data.drop('AGREEMENT_RK', axis=1, inplace=True)

# %%
data['PREVIOUS_CARD_NUM_UTILIZED'] = data['PREVIOUS_CARD_NUM_UTILIZED'].replace(data['PREVIOUS_CARD_NUM_UTILIZED'][0], 0)

# %%
category_columns = ['EDUCATION', 'MARITAL_STATUS', 'GEN_INDUSTRY', 'GEN_TITLE', 'ORG_TP_STATE', 'ORG_TP_FCAPITAL',
                    'JOB_DIR', 'FAMILY_INCOME', 'REG_ADDRESS_PROVINCE', 'FACT_ADDRESS_PROVINCE', 'POSTAL_ADDRESS_PROVINCE',
                    'TP_PROVINCE', 'REGION_NM']
data.drop(category_columns, axis=1).head()
# Out:
#    TARGET  AGE  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  GENDER  CHILD_TOTAL  \
# 0       0   49                  1                  0       1            2
# 1       0   32                  1                  0       1            3
# 2       0   52                  1                  0       1            4
# 3       0   39                  1                  0       1            1
# 4       0   30                  1                  0       0            0
#
#    DEPENDANTS PERSONAL_INCOME  REG_FACT_FL  FACT_POST_FL  REG_POST_FL  \
# 0           1            5000            1             1            1
# 1           3           12000            1             1            1
# 2           0            9000            1             1            1
# 3           1           25000            0             1            0
# 4           0           12000            1             1            1
#
#    REG_FACT_POST_FL  REG_FACT_POST_TP_FL  FL_PRESENCE_FL  OWN_AUTO  \
# ...

# %%
for i
