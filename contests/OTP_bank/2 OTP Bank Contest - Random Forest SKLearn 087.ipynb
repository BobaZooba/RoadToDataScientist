# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series

from sklearn.ensemble import RandomForestClassifier
from sklearn.

# %%
data = pd.read_csv('data/Credit_OTP_processed_087.csv', encoding='utf-8')
data.head()
# Out:
#    Unnamed: 0  AGE  PERSONAL_INCOME  OWN_AUTO    CREDIT  TERM  FST_PAYMENT  \
# 0           0   49           5000.0         0   8000.00     6       8650.0
# 1           1   32          12000.0         0  21650.00     6       4000.0
# 2           2   52           9000.0         0  33126.00    12       4000.0
# 3           3   39          25000.0         0   8491.82     6       5000.0
# 4           4   30          12000.0         0  21990.00    12       4000.0
#
#    FACT_LIVING_TERM  WORK_TIME  LOAN_NUM_TOTAL       ...         \
# 0               220       18.0               1       ...
# 1               137       97.0               1       ...
# 2               251       84.0               2       ...
# 3                36      168.0               1       ...
# 4                83      101.0               2       ...
#
#    REG_PHONE_FL_1  GEN_PHONE_FL_0  GEN_PHONE_FL_1  AGE_CATEGORY_1  \
# 0               0               0               1               0
# ...

# %%
data.drop('Unnamed: 0', axis=1, inplace=True)
data.head()
# Out:
#    AGE  PERSONAL_INCOME  OWN_AUTO    CREDIT  TERM  FST_PAYMENT  \
# 0   49           5000.0         0   8000.00     6       8650.0
# 1   32          12000.0         0  21650.00     6       4000.0
# 2   52           9000.0         0  33126.00    12       4000.0
# 3   39          25000.0         0   8491.82     6       5000.0
# 4   30          12000.0         0  21990.00    12       4000.0
#
#    FACT_LIVING_TERM  WORK_TIME  LOAN_NUM_TOTAL  LOAN_NUM_CLOSED  \
# 0               220       18.0               1                1
# 1               137       97.0               1                1
# 2               251       84.0               2                1
# 3                36      168.0               1                1
# 4                83      101.0               2                1
#
#         ...         REG_PHONE_FL_1  GEN_PHONE_FL_0  GEN_PHONE_FL_1  \
# 0       ...                      0               0               1
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(data.drop(['TARGET_0', 'TARGET_1'], axis=1), data[['TARGET_0', 'TARGET_1']], test_size=0.3)

# %%
forest=RandomForestClassifier(random_state=42, verbose=True, n_jobs=-1)
forest.fit(X_train, y_train)
# Out:
# Exception ignored in: <bound method DMatrix.__del__ of <xgboost.core.DMatrix object at 0x110f44cc0>>
# Traceback (most recent call last):
#   File "/anaconda/lib/python3.6/site-packages/xgboost/core.py", line 324, in __del__
#     _check_call(_LIB.XGDMatrixFree(self.handle))
# AttributeError: 'DMatrix' object has no attribute 'handle'
# [Parallel(n_jobs=-1)]: Done   6 out of  10 | elapsed:    0.1s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    0.1s finished
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=-1, oob_score=False, random_state=42,
#             verbose=True, warm_start=False)

# %%
forest.score(X_test, y_test)
# Out:
# [Parallel(n_jobs=8)]: Done   6 out of  10 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=8)]: Done  10 out of  10 | elapsed:    0.0s finished
# 0.87431574337639584

# %%
# Создаем объект с названиями предикторов
feat_labels = X_train.columns
# Создаем объект со значениями важностей, вычисленными моделью forest2
importances = forest.feature_importances_
# Задаем сортировку значений важности и сопоставляем названия предикторов важностям
indices = np.argsort(importances)[::-1]
for f in range(X_train.shape[1]):
    print("%2d) %-*s %f" % (f + 1, 35,
                            feat_labels[indices[f]],
                            importances[indices[f]]))
# Out:
#  1) PERSONAL_INCOME                     0.035051
#  2) CREDIT                              0.034092
#  3) FST_PAYMENT                         0.033904
#  4) FACT_LIVING_TERM                    0.033272
#  5) AGE                                 0.030700
#  6) WORK_TIME                           0.030556
#  7) TERM                                0.025236
#  8) LOAN_NUM_PAYM                       0.024152
#  9) LOAN_NUM_CLOSED                     0.011827
# 10) LOAN_AVG_DLQ_AMT                    0.009928
# 11) MARITAL_STATUS_Состою в браке       0.009246
# 12) LOAN_NUM_TOTAL                      0.009196
# 13) GPF_DOCUMENT_FL_0                   0.008359
# 14) LOAN_MAX_DLQ_AMT                    0.008018
# 15) GEN_TITLE_Специалист                0.007936
# 16) EDUCATION_Среднее                   0.007806
# 17) EDUCATION_Среднее специальное       0.007657
# 18) CHILD_TOTAL_0                       0.007509
# 19) ORG_TP_STATE_Государственная комп./учреж. 0.007338
# ...
